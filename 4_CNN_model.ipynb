# %% [markdown]
# <a href="https://colab.research.google.com/github/jiayeelim/AIROST_BrainTumorClassification/blob/main/4_CNN_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
import pickle
import time
import numpy as np
import keras.optimizers
from sklearn.metrics import classification_report

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.14.0

# %%
tensorboard = TensorBoard(log_dir='/content/drive/MyDrive/AIROST/Model/logs', histogram_freq=0,
                          write_graph=True, write_images=False)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# %%
# %cd /content/gdrive/My Drive/AIROST/Dataset
# !ls
# Out:
# /content/gdrive/My Drive/AIROST/Dataset
# test_data.npy	X_test.pickle	       X_train_batch3.pickle	Y_train.pickle
# Testing		X_train_batch0.pickle  X_train_combined.pickle
# train_data.npy	X_train_batch1.pickle  X_train.pickle
# Training	X_train_batch2.pickle  Y_test.pickle

# %%
import pickle

pickle_in = open("X_test.pickle","rb")
X_test = pickle.load(pickle_in)

pickle_in = open("X_train_combined.pickle","rb")
X_train = pickle.load(pickle_in)

pickle_in = open("Y_test.pickle","rb")
Y_test = pickle.load(pickle_in)

pickle_in = open("Y_train.pickle","rb")
Y_train = pickle.load(pickle_in)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-7d95435a4144> in <cell line: 3>()
#       1 import pickle
#       2
# ----> 3 pickle_in = open("X_test.pickle","rb")
#       4 X_test = pickle.load(pickle_in)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'X_test.pickle'

# %%
print(X_test.shape)
# Out:
# (8266, 150, 150, 3)

# %%
print(len(X_train))
# Out:
# 71791

# %%
X_train = np.array(X_train)
print(X_train.shape)
print(X_test.shape)
# Out:
# (71791, 150, 150, 3)
# (8266, 150, 150, 3)

# %%
dense_layers = [0,1,2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
# Out:
# 1-conv-32-nodes-0-dense-1701063010
# 2-conv-32-nodes-0-dense-1701063010
# 3-conv-32-nodes-0-dense-1701063010
# 1-conv-64-nodes-0-dense-1701063010
# 2-conv-64-nodes-0-dense-1701063010
# 3-conv-64-nodes-0-dense-1701063010
# 1-conv-128-nodes-0-dense-1701063010
# 2-conv-128-nodes-0-dense-1701063010
# 3-conv-128-nodes-0-dense-1701063010
# 1-conv-32-nodes-1-dense-1701063010
# 2-conv-32-nodes-1-dense-1701063010
# 3-conv-32-nodes-1-dense-1701063010
# 1-conv-64-nodes-1-dense-1701063010
# 2-conv-64-nodes-1-dense-1701063010
# 3-conv-64-nodes-1-dense-1701063010
# 1-conv-128-nodes-1-dense-1701063010
# 2-conv-128-nodes-1-dense-1701063010
# 3-conv-128-nodes-1-dense-1701063010
# 1-conv-32-nodes-2-dense-1701063010
# 2-conv-32-nodes-2-dense-1701063010
# 3-conv-32-nodes-2-dense-1701063010
# 1-conv-64-nodes-2-dense-1701063010
# 2-conv-64-nodes-2-dense-1701063010
# 3-conv-64-nodes-2-dense-1701063010
# 1-conv-128-nodes-2-dense-1701063010
# 2-conv-128-nodes-2-dense-1701063010
# ...

# %% [markdown]
# Try not to run this took too long to run

# %%
X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_test = np.array(X_test)
Y_test = np.array(Y_test)

dense_layers = [0,1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X_train.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())
            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))
                model.add(Dropout(0.33))

            model.add(Dense(4))
            model.add(Activation('softmax'))


            model.compile(loss='sparse_categorical_crossentropy',
              optimizer= "adam",
              metrics=['accuracy'],
              )

            #Fit the model
            model.fit(X_train, Y_train,
            batch_size=32,
            epochs=20,
            validation_data=(X_test,Y_test),
            callbacks=[tensorboard,es])

            #Score
            scores = model.evaluate(X_test, Y_test, verbose=1)
            print('Test loss:', scores[0])
            print('Test accuracy:', scores[1])

            #Save model
            model.save("/content/drive/MyDrive/AIROST/Model{}-model-{}-accuracy.h5".format(NAME,scores[1]))

            #precision    recall  f1-score   support
            y_pred = model.predict(X_test, batch_size=64, verbose=1)
            y_pred_bool = np.argmax(y_pred, axis=1)
            print(classification_report(Y_test, y_pred_bool))
            print()
            print()

# %% [markdown]
# Retry Using Original Data <br>
# Exclude Augmented Data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
import pickle
import time
import numpy as np
import keras.optimizers
from sklearn.metrics import classification_report

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.14.0

# %%
tensorboard = TensorBoard(log_dir='/content/drive/MyDrive/AIROST/Model/logs', histogram_freq=0,
                          write_graph=True, write_images=False)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# %%
# %cd /content/gdrive/My Drive/AIROST/Dataset
# !ls
# Out:
# /content/gdrive/My Drive/AIROST/Dataset
# Model1-conv-128-nodes-2-dense-1701675245-model-0.4060913622379303-accuracy.h5
# Model1-conv-32-nodes-2-dense-1701670782-model-0.1878172606229782-accuracy.h5
# Model1-conv-64-nodes-2-dense-1701672062-model-0.1878172606229782-accuracy.h5
# Model2-conv-128-nodes-2-dense-1701677473-model-0.7055837512016296-accuracy.h5
# Model2-conv-32-nodes-2-dense-1701671113-model-0.25380709767341614-accuracy.h5
# Model2-conv-64-nodes-2-dense-1701672758-model-0.624365508556366-accuracy.h5
# Model3-conv-128-nodes-1-dense-1701627892-model-0.6878172755241394-accuracy.h5
# Model3-conv-32-nodes-2-dense-1701671550-model-0.25380709767341614-accuracy.h5
# Model3-conv-64-nodes-2-dense-1701673882-model-0.5837563276290894-accuracy.h5
# Model-accuracy.h5
# test_data_new.npy
# test_data.npy
# Testing
# train_data_new.npy
# train_data.npy
# Training
# X_test_new.pickle
# X_test.pickle
# X_train_batch0.pickle
# X_train_batch1.pickle
# X_train_batch2.pickle
# ...

# %%
import pickle

pickle_in = open("X_test_new.pickle","rb")
X_test = pickle.load(pickle_in)

pickle_in = open("X_train_new.pickle","rb")
X_train = pickle.load(pickle_in)

pickle_in = open("Y_test_new.pickle","rb")
Y_test = pickle.load(pickle_in)

pickle_in = open("Y_train_new.pickle","rb")
Y_train = pickle.load(pickle_in)

# %%
dense_layers = [0,1,2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
# Out:
# 1-conv-32-nodes-0-dense-1701667333
# 2-conv-32-nodes-0-dense-1701667333
# 3-conv-32-nodes-0-dense-1701667333
# 1-conv-64-nodes-0-dense-1701667333
# 2-conv-64-nodes-0-dense-1701667333
# 3-conv-64-nodes-0-dense-1701667333
# 1-conv-128-nodes-0-dense-1701667333
# 2-conv-128-nodes-0-dense-1701667333
# 3-conv-128-nodes-0-dense-1701667333
# 1-conv-32-nodes-1-dense-1701667333
# 2-conv-32-nodes-1-dense-1701667333
# 3-conv-32-nodes-1-dense-1701667333
# 1-conv-64-nodes-1-dense-1701667333
# 2-conv-64-nodes-1-dense-1701667333
# 3-conv-64-nodes-1-dense-1701667333
# 1-conv-128-nodes-1-dense-1701667333
# 2-conv-128-nodes-1-dense-1701667333
# 3-conv-128-nodes-1-dense-1701667333
# 1-conv-32-nodes-2-dense-1701667333
# 2-conv-32-nodes-2-dense-1701667333
# 3-conv-32-nodes-2-dense-1701667333
# 1-conv-64-nodes-2-dense-1701667333
# 2-conv-64-nodes-2-dense-1701667333
# 3-conv-64-nodes-2-dense-1701667333
# 1-conv-128-nodes-2-dense-1701667333
# 2-conv-128-nodes-2-dense-1701667333
# ...

# %%
X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_test = np.array(X_test)
Y_test = np.array(Y_test)

dense_layers = [0,1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X_train.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())
            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))
                model.add(Dropout(0.33))

            model.add(Dense(4))
            model.add(Activation('softmax'))


            model.compile(loss='sparse_categorical_crossentropy',
              optimizer= "adam",
              metrics=['accuracy'],
              )

            #Fit the model
            model.fit(X_train, Y_train,
            batch_size=32,
            epochs=20,
            validation_data=(X_test,Y_test),
            callbacks=[tensorboard,es])

            #Score
            scores = model.evaluate(X_test, Y_test, verbose=1)
            print('Test loss:', scores[0])
            print('Test accuracy:', scores[1])

            #Save model
            model.save("Model{}-model-{}-accuracy.h5".format(NAME,scores[1]))

            #precision    recall  f1-score   support
            y_pred = model.predict(X_test, batch_size=64, verbose=1)
            y_pred_bool = np.argmax(y_pred, axis=1)
            print(classification_report(Y_test, y_pred_bool))
            print()
            print()
# Out:
# 1-conv-32-nodes-0-dense-1701599118
# Epoch 1/20
# 90/90 [==============================] - 48s 520ms/step - loss: 240.5778 - accuracy: 0.5474 - val_loss: 34.2365 - val_accuracy: 0.4721
# Epoch 2/20
# 90/90 [==============================] - 47s 521ms/step - loss: 1.2449 - accuracy: 0.8641 - val_loss: 26.2305 - val_accuracy: 0.5990
# Epoch 3/20
# 90/90 [==============================] - 43s 482ms/step - loss: 0.2676 - accuracy: 0.9617 - val_loss: 24.3283 - val_accuracy: 0.6574
# Epoch 4/20
# 90/90 [==============================] - 46s 513ms/step - loss: 0.0771 - accuracy: 0.9899 - val_loss: 22.0851 - val_accuracy: 0.6929
# Epoch 5/20
# 90/90 [==============================] - 43s 474ms/step - loss: 0.0287 - accuracy: 0.9944 - val_loss: 23.1060 - val_accuracy: 0.6954
# Epoch 6/20
# 90/90 [==============================] - 45s 503ms/step - loss: 0.0092 - accuracy: 0.9979 - val_loss: 23.2764 - val_accuracy: 0.6980
# Epoch 7/20
# ...

# %%
# Run the rest that did not get to run due to time out
X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_test = np.array(X_test)
Y_test = np.array(Y_test)

dense_layers = [1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X_train.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())
            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))
                model.add(Dropout(0.33))

            model.add(Dense(4))
            model.add(Activation('softmax'))


            model.compile(loss='sparse_categorical_crossentropy',
              optimizer= "adam",
              metrics=['accuracy'],
              )

            #Fit the model
            model.fit(X_train, Y_train,
            batch_size=32,
            epochs=20,
            validation_data=(X_test,Y_test),
            callbacks=[tensorboard,es])

            #Score
            scores = model.evaluate(X_test, Y_test, verbose=1)
            print('Test loss:', scores[0])
            print('Test accuracy:', scores[1])

            #Save model
            model.save("Model{}-model-{}-accuracy.h5".format(NAME,scores[1]))

            #precision    recall  f1-score   support
            y_pred = model.predict(X_test, batch_size=64, verbose=1)
            y_pred_bool = np.argmax(y_pred, axis=1)
            print(classification_report(Y_test, y_pred_bool))
            print()
            print()
# Out:
# 1-conv-32-nodes-1-dense-1701627892
# Epoch 1/20
# 90/90 [==============================] - 59s 641ms/step - loss: 20.6118 - accuracy: 0.2965 - val_loss: 1.3885 - val_accuracy: 0.2538
# Epoch 2/20
# 90/90 [==============================] - 62s 688ms/step - loss: 1.3686 - accuracy: 0.2920 - val_loss: 1.3921 - val_accuracy: 0.2538
# Epoch 3/20
# 90/90 [==============================] - 54s 597ms/step - loss: 1.3626 - accuracy: 0.2913 - val_loss: 1.3964 - val_accuracy: 0.2538
# Epoch 4/20
# 90/90 [==============================] - 56s 627ms/step - loss: 1.3598 - accuracy: 0.2965 - val_loss: 1.4007 - val_accuracy: 0.2538
# Epoch 5/20
# 90/90 [==============================] - 56s 626ms/step - loss: 1.3574 - accuracy: 0.2882 - val_loss: 1.4053 - val_accuracy: 0.2538
# Epoch 6/20
# 90/90 [==============================] - 55s 618ms/step - loss: 1.3549 - accuracy: 0.2878 - val_loss: 1.4102 - val_accuracy: 0.2538
# Epoch 6: early stopping
# ...

# %%
# Run the rest that did not get to run due to time out
X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_test = np.array(X_test)
Y_test = np.array(Y_test)

dense_layers = [2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X_train.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())
            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))
                model.add(Dropout(0.33))

            model.add(Dense(4))
            model.add(Activation('softmax'))


            model.compile(loss='sparse_categorical_crossentropy',
              optimizer= "adam",
              metrics=['accuracy'],
              )

            #Fit the model
            model.fit(X_train, Y_train,
            batch_size=32,
            epochs=20,
            validation_data=(X_test,Y_test),
            callbacks=[tensorboard,es])

            #Score
            scores = model.evaluate(X_test, Y_test, verbose=1)
            print('Test loss:', scores[0])
            print('Test accuracy:', scores[1])

            #Save model
            model.save("Model{}-model-{}-accuracy.h5".format(NAME,scores[1]))

            #precision    recall  f1-score   support
            y_pred = model.predict(X_test, batch_size=64, verbose=1)
            y_pred_bool = np.argmax(y_pred, axis=1)
            print(classification_report(Y_test, y_pred_bool))
            print()
            print()
# Out:
# 1-conv-32-nodes-2-dense-1701670782
# Epoch 1/20
# 90/90 [==============================] - 50s 538ms/step - loss: 27.8911 - accuracy: 0.2906 - val_loss: 1.3994 - val_accuracy: 0.1878
# Epoch 2/20
# 90/90 [==============================] - 48s 535ms/step - loss: 1.4047 - accuracy: 0.2871 - val_loss: 1.4139 - val_accuracy: 0.1878
# Epoch 3/20
# 90/90 [==============================] - 50s 557ms/step - loss: 1.3538 - accuracy: 0.2861 - val_loss: 1.4227 - val_accuracy: 0.1878
# Epoch 4/20
# 90/90 [==============================] - 49s 543ms/step - loss: 1.3530 - accuracy: 0.2934 - val_loss: 1.4275 - val_accuracy: 0.1878
# Epoch 5/20
# 90/90 [==============================] - 46s 515ms/step - loss: 1.3506 - accuracy: 0.2847 - val_loss: 1.4305 - val_accuracy: 0.1878
# Epoch 6/20
# 90/90 [==============================] - 47s 522ms/step - loss: 1.3507 - accuracy: 0.2871 - val_loss: 1.4330 - val_accuracy: 0.1878
# Epoch 6: early stopping
# ...

# %%
# Run the rest that did not get to run due to time out
import numpy as np
import time


X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_test = np.array(X_test)
Y_test = np.array(Y_test)
# only 1 model trained
model = Sequential()

model.add(Conv2D(128, (3, 3), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.33))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.33))

model.add(Dense(4))
model.add(Activation('softmax'))

model.compile(loss='sparse_categorical_crossentropy',optimizer= "adam",metrics=['accuracy'],)

#Fit the model
model.fit(X_train, Y_train,batch_size=32,epochs=20, validation_data=(X_test,Y_test),callbacks=[tensorboard,es])

#Score
scores = model.evaluate(X_test, Y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# Save model in the native Keras format
model.save("Model3-conv-128-nodes-2-dense-1701627892-model-{}-accuracy.h5".format(scores[1]))

#precision    recall  f1-score   support
y_pred = model.predict(X_test, batch_size=64, verbose=1)
y_pred_bool = np.argmax(y_pred, axis=1)
print(classification_report(Y_test, y_pred_bool))
print()
print()
# Out:
# Epoch 1/20
# 90/90 [==============================] - 476s 5s/step - loss: 2.8278 - accuracy: 0.5000 - val_loss: 1.6328 - val_accuracy: 0.3680
# Epoch 2/20
# 90/90 [==============================] - 471s 5s/step - loss: 0.8249 - accuracy: 0.6662 - val_loss: 1.6445 - val_accuracy: 0.4569
# Epoch 3/20
# 90/90 [==============================] - 471s 5s/step - loss: 0.6616 - accuracy: 0.7429 - val_loss: 1.8290 - val_accuracy: 0.4695
# Epoch 4/20
# 90/90 [==============================] - 471s 5s/step - loss: 0.5535 - accuracy: 0.7895 - val_loss: 1.6280 - val_accuracy: 0.5558
# Epoch 5/20
# 90/90 [==============================] - 470s 5s/step - loss: 0.4572 - accuracy: 0.8282 - val_loss: 1.6973 - val_accuracy: 0.5711
# Epoch 6/20
# 90/90 [==============================] - 468s 5s/step - loss: 0.3699 - accuracy: 0.8526 - val_loss: 2.3143 - val_accuracy: 0.5863
# Epoch 7/20
# ...
